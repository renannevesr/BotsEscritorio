# %%
import pandas as pd
df_cadastro = pd.read_csv('202404_Cadastro.csv', encoding="ISO-8859-1",sep=",")
df_remuneracao = pd.read_csv('202404_Remuneracao.csv', encoding="ISO-8859-1",sep=";")
# Out:
# C:\Users\Renan\AppData\Local\Temp\ipykernel_13076\4040950136.py:3: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_remuneracao = pd.read_csv('202404_Remuneracao.csv', encoding="ISO-8859-1",sep=";")

# %%
df_cadastro
# Out:
#        Id_SERVIDOR_PORTAL                                  NOME  \
# 0                 1473224            ABDON BRENO VELOZO SANTANA
# 1                  160793            ABEL AARAO CALDAS DA COSTA
# 2                 1557959        ABEL BANDEIRA DOS SANTOS FIRST
# 3                 1582094  ABELARDO DE ABREU RODRIGUES DA SILVA
# 4                 2139830           ABELINA DA CONCEICAO SANTOS
# ...                   ...                                   ...
# 22503             3934551  *** PENSIONISTA MENOR DE 16 ANOS ***
# 22504             3935027  *** PENSIONISTA MENOR DE 16 ANOS ***
# 22505             3935424  *** PENSIONISTA MENOR DE 16 ANOS ***
# 22506             3936002  *** PENSIONISTA MENOR DE 16 ANOS ***
# 22507                 -11                              Sigiloso
#
#                   CPF MATRICULA CPF_REPRESENTANTE_LEGAL  \
# 0      ***.157.724-**   009****          ***.170.254-**
# 1      ***.520.343-**   022****          ***.383.273-**
# ...

# %%
df_remuneracao
# Out:
#                                                       ANO  MES  \
# 0                                                    2024  4.0
# 1                                                    2024  4.0
# 2                                                    2024  4.0
# 3                                                    2024  4.0
# 4                                                    2024  4.0
# ...                                                   ...  ...
# 277625                                               2024  4.0
# 277626                                               2024  4.0
# 277627                                               2024  4.0
# 277628                                               2024  4.0
# 277629  (*) Verbas indenizatórias são as parcelas inde...  NaN
#
#         Id_SERVIDOR_PORTAL             CPF  \
# 0                2198208.0  ***.394.928-**
# 1                2682947.0  ***.023.296-**
# 2                3449391.0  ***.421.211-**
# ...

# %%
print(df_cadastro.columns)
# Out:
# Index(['Id_SERVIDOR_PORTAL', 'NOME', 'CPF', 'MATRICULA',
#        'CPF_REPRESENTANTE_LEGAL', 'NOME_REPRESENTANTE_LEGAL',
#        'CPF_INSTITUIDOR_PENSAO', 'NOME_INSTITUIDOR_PENSAO', 'COD_TIPO_PENSAO',
#        'TIPO_PENSAO', 'DATA_INICIO_PENSAO',
#        'DESCRICAO_CARGO_INSTITUIDOR_PENSAO',
#        'COD_UORG_LOTACAO_INSTITUIDOR_PENSAO',
#        'UORG_LOTACAO_INSTITUIDOR_PENSAO', 'COD_ORG_LOTACAO_INSTITUIDOR_PENSAO',
#        'ORG_LOTACAO_INSTITUIDOR_PENSAO',
#        'COD_ORGSUP_LOTACAO_INSTITUIDOR_PENSAO',
#        'ORGSUP_LOTACAO_INSTITUIDOR_PENSAO', 'COD_TIPO_VINCULO', 'TIPO_VINCULO',
#        'SITUACAO_VINCULO', 'REGIME_JURIDICO_INSTITUIDOR_PENSAO',
#        'JORNADA_DE_TRABALHO_INSTITUIDOR_PENSAO',
#        'DATA_INGRESSO_CARGOFUNCAO_INSTITUIDOR_PENSAO',
#        'DATA_NOMEACAO_CARGOFUNCAO_INSTITUIDOR_PENSAO',
#        'DATA_INGRESSO_ORGAO_INSTITUIDOR_PENSAO',
#        'DOCUMENTO_INGRESSO_SERVICOPUBLICO_INSTITUIDOR_PENSAO',
# ...

# %%
print(df_remuneracao.columns)
# Out:
# Index(['ANO', 'MES', 'Id_SERVIDOR_PORTAL', 'CPF', 'NOME',
#        'REMUNERAÇÃO BÁSICA BRUTA (R$)', 'REMUNERAÇÃO BÁSICA BRUTA (U$)',
#        'ABATE-TETO (R$)', 'ABATE-TETO (U$)', 'GRATIFICAÇÃO NATALINA (R$)',
#        'GRATIFICAÇÃO NATALINA (U$)',
#        'ABATE-TETO DA GRATIFICAÇÃO NATALINA (R$)',
#        'ABATE-TETO DA GRATIFICAÇÃO NATALINA (U$)', 'FÉRIAS (R$)',
#        'FÉRIAS (U$)', 'OUTRAS REMUNERAÇÕES EVENTUAIS (R$)',
#        'OUTRAS REMUNERAÇÕES EVENTUAIS (U$)', 'IRRF (R$)', 'IRRF (U$)',
#        'PSS/RPGS (R$)', 'PSS/RPGS (U$)', 'DEMAIS DEDUÇÕES (R$)',
#        'DEMAIS DEDUÇÕES (U$)', 'PENSÃO MILITAR (R$)', 'PENSÃO MILITAR (U$)',
#        'FUNDO DE SAÚDE (R$)', 'FUNDO DE SAÚDE (U$)',
#        'TAXA DE OCUPAÇÃO IMÓVEL FUNCIONAL (R$)',
#        'TAXA DE OCUPAÇÃO IMÓVEL FUNCIONAL (U$)',
#        'REMUNERAÇÃO APÓS DEDUÇÕES OBRIGATÓRIAS (R$)',
#        'REMUNERAÇÃO APÓS DEDUÇÕES OBRIGATÓRIAS (U$)',
# ...

# %%
df_filtrado_pensionista = df_pensionista.loc[:, ['NOME DO SERVIDOR INSTITUIDOR', 'CPF SERVIDOR INSTITUIDOR', 'NOME DO BENEFICIARIO', 'CPF DO BENEFICIARIO','CARGO SERVIDOR INSTITUIDOR','TIPO DE BENEFICIARIO','RENDIMENTO BRUTO','RENDIMENTO LIQUIDO']]
df_filtrado_pensionista = df_filtrado_pensionista.dropna(subset=['TIPO DE BENEFICIARIO'])
